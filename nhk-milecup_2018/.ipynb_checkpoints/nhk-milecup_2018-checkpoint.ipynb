# %%
import pandas as pd

# %%
# 過去のデータ分析
past_race_data = pd.read_csv('past_race_data.csv',
                             encoding='SHIFT-JIS',
                             header=0)
past_race_data
# Out:
#      Unnamed: 0  着順  枠番  馬番         馬名  性齢  斤量    騎手     タイム     着差   ...    \
# 0             0   1   7  13  シーキングザパール  牝4  55    武豊  1:33.1    NaN   ...
# 1             1   2   7  14   ブレーブテンダー  牡4  57  松永幹夫  1:33.4  1.3/4   ...
# 2             2   3   6  12  ショウナンナンバー  牡4  57   吉田豊  1:33.4     クビ   ...
# 3             3   4   8  16     ヒコーキグモ  牡4  57  蛯名正義  1:33.4    アタマ   ...
# 4             4   5   3   5   オースミジェット  牡4  57  福永祐一  1:33.5    1/2   ...
# 5             5   6   8  18  パーソナリティワン  牡4  57  大西直宏  1:33.6    3/4   ...
# 6             6   7   8  17    パームシャドウ  牡4  57  岡部幸雄  1:33.8      1   ...
# 7             7   8   3   6   スーパーナカヤマ  牡4  57   的場均  1:33.9    3/4   ...
# 8             8   9   6  11   シルクマスタング  牡4  57  久保田英  1:34.0    1/2   ...
# 9             9  10   7  15   ワシントンカラー  牡4  57  柴田善臣  1:34.0     クビ   ...
# 10           10  11   1   1    キタサンフドー  牡4  57   高橋亮  1:34.1     クビ   ...
# 11           11  12   5  10  ペイストリーシェフ  牡4  57  小野次郎  1:34.1     クビ   ...
# ...

# %%
# 過去の人気馬とその結果について調べる
past_first_choices = past_race_data[past_race_data['人気'] == 1]
past_first_choices
# Out:
#      Unnamed: 0  着順  枠番  馬番         馬名  性齢  斤量    騎手     タイム     着差   ...    \
# 0             0   1   7  13  シーキングザパール  牝4  55    武豊  1:33.1    NaN   ...
# 18            0   1   5   9  エルコンドルパサー  牡4  57   的場均  1:33.7    NaN   ...
# 44            9  10   1   1  エイシンキャメロン  牡4  57    武豊  1:35.1  1.1/2   ...
# 55            2   3   5  10   マチカネホクシン  牡4  57    武豊  1:33.8  1.3/4   ...
# 71            0   1   2   4       クロフネ  牡3  57    武豊  1:33.0    NaN   ...
# 91            2   3   5   9   タニノギムレット  牡3  57    武豊  1:33.5    3/4   ...
# 117          10  11   6  12  ゴールデンキャスト  牡3  57    武豊  1:35.0    アタマ   ...
# 125           0   1   7  13   キングカメハメハ  牡3  57  安藤勝己  1:32.5    NaN   ...
# 146           3   4   1   2    ペールギュント  牡3  57    武豊  1:34.3      2   ...
# 166           5   6   8  18  フサイチリシャール  牡3  57  福永祐一  1:34.0  1.3/4   ...
# 180           1   2   5  10   ローレルゲレイロ  牡3  57  藤田伸二  1:34.4    1/2   ...
# 197           0   1   5   9    ディープスカイ  牡3  57  四位洋文  1:34.2    NaN   ...
# ...

# %%
# 2017 アエロリット
aelo_lit = pd.read_html('http://db.netkeiba.com/horse/result/2014105785/')
aelo_lit = aelo_lit[0]
aelo_lit = aelo_lit.query('日付 < "2017/05/07"')
aelo_lit
# Out:
#            日付    開催 天気   R            レース名  映像  頭数  枠番  馬番   オッズ   ...     着差  \
# 4  2017/04/09  2阪神6  曇  11         桜花賞(G1) NaN  17   6  12  23.6   ...    0.2
# 5  2017/02/11  1東京5  晴  11  デイリー杯クイーンC(G3) NaN  16   6  11   8.8   ...    0.1
# 6  2017/01/08  1中山3  雨  11      フェアリーS(G3) NaN  16   2   3   2.6   ...    0.1
# 7  2016/10/02  4中山8  晴   9    サフラン賞(500万下) NaN  12   8  11   2.2   ...    0.0
# 8  2016/06/19  3東京6  曇   6            2歳新馬 NaN  14   2   2   3.0   ...   -0.3
#
#    ﾀｲﾑ指数     通過        ペース    上り       馬体重 厩舎ｺﾒﾝﾄ  備考     勝ち馬(2着馬)      賞金
# 4     **  14-14  34.7-36.2  35.0   480(-6)    NaN NaN       レーヌミノル   920.0
# 5     **    6-3  34.8-34.1  33.9   486(-6)    NaN NaN     アドマイヤミヤビ  1416.6
# 6     **  2-2-2  34.7-36.7  36.4  492(+10)    NaN NaN    ライジングリーズン  1417.0
# 7     **  2-3-2  35.2-35.9  35.6   482(+6)    NaN NaN     トーホウアイレス   408.0
# 8     **    2-2  36.6-33.7  33.5    476(0)    NaN NaN  (ダイイチターミナル)   700.0
#
# [5 rows x 28 columns]

# %%
# アイスフィヨルド
ice_fiyold = pd.read_html('http://db.netkeiba.com/horse/result/2015102841/')
ice_fiyold = ice_fiyold[0]
ice_fiyold
# Out:
#            日付    開催 天気   R           レース名  映像  頭数  枠番  馬番   オッズ  ...     着差  \
# 0  2018/04/07  3中山5  曇  11  ニュージーランドT(G2) NaN  15   3   4  17.9  ...    0.3
# 1  2018/03/18  2中山8  曇   6        3歳500万下 NaN  11   6   7   3.6  ...    0.0
# 2  2018/02/17  1東京7  晴   6        3歳500万下 NaN  15   7  12  16.5  ...    0.1
# 3  2018/01/27  1東京1  晴  10     クロッカスS(OP) NaN  13   5   7  20.0  ...    0.3
# 4  2017/12/24  5中山8  曇   8  クリスマスローズS(OP) NaN  15   2   3   6.7  ...    0.9
# 5  2017/11/04  5東京1  晴   4          2歳未勝利 NaN  18   8  16   3.4  ...   -0.5
# 6  2017/10/14  4東京4  曇   3          2歳未勝利 NaN  10   8  10   5.5  ...    0.4
# 7  2017/09/23  4中山6  曇   3          2歳未勝利 NaN  11   1   1   8.0  ...    0.4
# 8  2017/09/09  4中山1  晴   2          2歳未勝利 NaN  12   8  11   8.0  ...    0.5
# 9  2017/08/19  2新潟7  曇   6           2歳新馬 NaN  18   1   1  39.2  ...    0.3
#
#    ﾀｲﾑ指数       通過        ペース    上り      馬体重 厩舎ｺﾒﾝﾄ  備考    勝ち馬(2着馬)     賞金
# ...

# %%
# アルジャーノン
arjarnon = pd.read_html('http://db.netkeiba.com/horse/result/2015101210/')
arjarnon = arjarnon[0]
arjarnon
# Out:
#            日付    開催 天気  R     レース名  映像  頭数  枠番  馬番    オッズ  ...      着差  ﾀｲﾑ指数  \
# 0  2018/04/22  3京都2  晴  6  3歳500万下 NaN  11   2   2   14.6  ...    -0.2     **
# 1  2018/04/07  2阪神5  晴  4    3歳未勝利 NaN  18   3   5   13.6  ...    -0.1     **
# 2  2018/03/25  2阪神2  晴  5    3歳未勝利 NaN  15   6  10   75.8  ...     0.7     **
# 3  2018/03/04  1阪神4  晴  5    3歳未勝利 NaN  16   5  10   25.5  ...     1.0     **
# 4  2017/12/23  5阪神7  晴  4    2歳未勝利 NaN  18   2   3   17.3  ...    10.1     **
# 5  2017/12/09  4中京3  晴  7    2歳未勝利 NaN  15   4   8    6.0  ...     0.5     **
# 6  2017/11/25  5京都7  晴  5     2歳新馬 NaN  18   5  10  108.4  ...     0.2     **
#
#       通過        ペース    上り       馬体重 厩舎ｺﾒﾝﾄ  備考   勝ち馬(2着馬)     賞金
# 0    2-2  34.8-35.5  35.4    434(0)    NaN NaN  (ロードイヒラニ)  720.0
# 1    4-4  34.5-36.9  36.6   434(+2)    NaN NaN  (ハードカウント)  500.0
# 2    3-2  36.5-34.2  34.6   432(-6)    NaN NaN    レーヴドリーブ   75.0
# 3  16-14  36.1-34.1  33.8  438(-12)    NaN NaN       ロケット    NaN
# ...

# %%
# アンコールプリュ
anchol_plyu = pd.read_html('http://db.netkeiba.com/horse/result/2015104721/')
anchol_plyu = anchol_plyu[0]
anchol_plyu
# Out:
#            日付    開催 天気   R           レース名  映像  頭数  枠番  馬番   オッズ   ...     着差  \
# 0  2018/04/08  2阪神6  晴  11        桜花賞(G1) NaN  17   2   4  45.4   ...    1.2
# 1  2018/03/11  1阪神6  晴  11  フィリーズレビュー(G2) NaN  18   5   9   4.4   ...    0.1
# 2  2017/12/16  4中京5  曇  10   つわぶき賞(500万下) NaN  16   8  16   9.2   ...   -0.2
# 3  2017/12/03  5阪神2  晴   5           2歳新馬 NaN  15   4   7   1.5   ...   -0.1
#
#    ﾀｲﾑ指数     通過        ペース    上り      馬体重 厩舎ｺﾒﾝﾄ  備考    勝ち馬(2着馬)      賞金
# 0     **   10-9  34.5-34.4  34.9  422(-4)    NaN NaN     アーモンドアイ     NaN
# 1     **  16-12  33.7-36.1  34.7   426(0)    NaN NaN     リバティハイツ  2138.4
# 2     **  13-11  35.7-34.4  33.5   426(0)    NaN NaN     (モデレイト)  1039.9
# 3     **    3-4  35.4-35.6  35.3   426(0)    NaN NaN  (ロードヴォラーレ)   700.0
#
# [4 rows x 28 columns]

# %%
kasias = pd.read_html('http://db.netkeiba.com/horse/result/2015105872/')
kasias = kasias[0]
kasias
# Out:
#            日付    開催 天気   R            レース名  映像  頭数  枠番  馬番   オッズ   ...     着差  \
# 0  2018/04/07  3中山5  曇  11   ニュージーランドT(G2) NaN  15   4   6   6.9   ...    0.4
# 1  2018/01/08  1京都3  雨  11  日刊スポシンザン記念(G3) NaN  11   8  11   7.5   ...    0.3
# 2  2017/12/17  5阪神6  晴  11  朝日フューチュリティ(G1) NaN  16   6  11  48.0   ...    0.8
# 3  2017/11/04  5東京1  曇  11      京王杯2歳S(G2) NaN  11   6   6  13.9   ...    0.3
# 4  2017/07/23  2函館6  晴  11       函館2歳S(G3) NaN  15   6  11   3.0   ...    0.0
# 5  2017/07/01  1函館5  曇   1           2歳未勝利 NaN  10   4   4   2.2   ...   -0.6
# 6  2017/06/18  1函館2  晴   5            2歳新馬 NaN   8   8   8  12.9   ...    0.0
#
#    ﾀｲﾑ指数     通過        ペース    上り       馬体重 厩舎ｺﾒﾝﾄ  備考     勝ち馬(2着馬)      賞金
# 0     **  1-1-1  35.2-35.1  35.5   478(-4)    NaN NaN          カツジ     NaN
# 1     **    1-1  35.7-35.3  35.6   482(+2)    NaN NaN      アーモンドアイ   956.5
# 2     **    3-3  35.2-34.0  34.5  480(+10)    NaN NaN     ダノンプレミアム     NaN
# ...

# %%
katsuji = pd.read_html('http://db.netkeiba.com/horse/result/2015105461/')
katsuji = katsuji[0]
katsuji
# Out:
#            日付    開催 天気   R           レース名  映像  頭数  枠番  馬番  オッズ   ...     着差  \
# 0  2018/04/07  3中山5  曇  11  ニュージーランドT(G2) NaN  15   3   5  4.0   ...    0.0
# 1  2018/02/04  2京都4  晴  11      きさらぎ賞(G3) NaN  10   8  10  5.0   ...    0.8
# 2  2017/11/11  5京都3  晴  11   デイリー杯2歳S(G2) NaN   9   8   8  5.4   ...    0.2
# 3  2017/10/21  4京都6  雨   5           2歳新馬 NaN  15   4   6  2.1   ...   -0.2
#
#    ﾀｲﾑ指数        通過        ペース    上り       馬体重 厩舎ｺﾒﾝﾄ  備考     勝ち馬(2着馬)      賞金
# 0     **  13-14-10  35.2-35.1  33.9  478(-12)    NaN NaN  (ケイアイノーテック)  5510.6
# 1     **       3-3  36.8-35.4  36.0  490(+14)    NaN NaN     サトノフェイバー   380.0
# 2     **       2-2  35.7-35.3  35.0   476(+4)    NaN NaN       ジャンダルム  1509.2
# 3     **       5-5  36.5-36.3  35.9    472(0)    NaN NaN    (コンパウンダー)   700.0
#
# [4 rows x 28 columns]

# %%
gibeon = pd.read_html('http://db.netkeiba.com/horse/result/2015104317/')
gibeon = gibeon[0]
gibeon
# Out:
#            日付    開催 天気   R           レース名  映像  頭数  枠番  馬番  オッズ   ...     着差  \
# 0  2018/03/24  2阪神1  晴  11        毎日杯(G3) NaN  10   5   5  3.9   ...    0.3
# 1  2018/02/17  1東京7  晴   9  フリージア賞(500万下) NaN  11   6   7  3.3   ...   -0.1
# 2  2017/12/17  5阪神6  晴   5           2歳新馬 NaN  10   8  10  1.4   ...   -0.1
#
#    ﾀｲﾑ指数     通過        ペース    上り       馬体重 厩舎ｺﾒﾝﾄ  備考     勝ち馬(2着馬)      賞金
# 0     **    5-5  36.0-34.1  34.0   502(-2)    NaN NaN    ブラストワンピース  1511.0
# 1     **  8-7-7  37.4-34.2  33.7  504(-12)    NaN NaN  (マイネルファンロン)  1029.4
# 2     **    2-2  37.9-33.8  33.7    516(0)    NaN NaN       (ミアグア)   700.0
#
# [3 rows x 28 columns]

# %%
keiai_notec = pd.read_html('http://db.netkeiba.com/horse/result/2015100344/')
keiai_notec = keiai_notec[0]
keiai_notec
# Out:
#            日付    開催 天気   R            レース名  映像  頭数  枠番  馬番   オッズ   ...     着差  \
# 0  2018/04/07  3中山5  曇  11   ニュージーランドT(G2) NaN  15   8  14   3.2   ...    0.0
# 1  2018/03/11  1阪神6  晴   6         3歳500万下 NaN   9   5   5   1.2   ...   -0.7
# 2  2018/02/10  2京都5  雨   9     こぶし賞(500万下) NaN  14   2   2   2.1   ...    0.2
# 3  2017/12/17  5阪神6  晴  11  朝日フューチュリティ(G1) NaN  16   3   5  26.3   ...    0.6
# 4  2017/11/11  5京都3  晴  11    デイリー杯2歳S(G2) NaN   9   5   5   5.2   ...    0.6
# 5  2017/06/03  3阪神1  晴   5            2歳新馬 NaN  10   2   2   2.5   ...   -0.3
#
#    ﾀｲﾑ指数     通過        ペース    上り       馬体重 厩舎ｺﾒﾝﾄ  備考     勝ち馬(2着馬)      賞金
# 0     **  8-8-5  35.2-35.1  34.5  456(-12)    NaN NaN          カツジ  2231.6
# 1     **    6-7  35.4-34.4  33.9    468(0)    NaN NaN    (ナリタハーデス)   720.0
# 2     **   11-4  34.0-37.4  36.7   468(-2)    NaN NaN    パクスアメリカーナ   409.4
# 3     **  10-10  35.2-34.0  33.8   470(-2)    NaN NaN     ダノンプレミアム  1100.0
# ...

# %%
tower_of_london = pd.read_html('http://db.netkeiba.com/horse/result/2015101621/')
tower_of_london = tower_of_london[0]
tower_of_london
# Out:
#            日付    開催 天気   R            レース名  映像  頭数  枠番  馬番  オッズ   ...     着差  \
# 0  2018/04/14  2阪神7  雨  11     アーリントンC(G3) NaN  13   5   6  3.1   ...   -0.1
# 1  2017/12/17  5阪神6  晴  11  朝日フューチュリティ(G1) NaN  16   2   3  3.9   ...    0.6
# 2  2017/11/04  5東京1  曇  11      京王杯2歳S(G2) NaN  11   1   1  1.8   ...   -0.3
# 3  2017/09/23  4阪神6  曇   9       ききょうS(OP) NaN  11   8  11  1.8   ...   -0.6
# 4  2017/08/20  2札幌2  晴   9      クローバー賞(OP) NaN  11   8  10  1.7   ...    0.1
# 5  2017/07/29  1札幌1  曇   5            2歳新馬 NaN   9   8   8  4.0   ...   -0.4
#
#    ﾀｲﾑ指数     通過        ペース    上り       馬体重 厩舎ｺﾒﾝﾄ  備考     勝ち馬(2着馬)      賞金
# 0     **    9-9  34.5-34.7  34.2   510(-8)    NaN NaN  (パクスアメリカーナ)  3846.9
# 1     **    7-7  35.2-34.0  34.0   518(+2)    NaN NaN     ダノンプレミアム  1816.4
# 2     **    6-7  36.0-33.8  33.2   516(+4)    NaN NaN       (カシアス)  3839.2
# 3     **    9-7  33.5-36.5  35.2  512(-10)    NaN NaN   (バーニングペスカ)  1623.8
# ...

# %%
danon_smash = pd.read_html('http://db.netkeiba.com/horse/result/2015102377/')
danon_smash = danon_smash[0]
danon_smash
# Out:
#            日付     開催 天気   R            レース名  映像  頭数  枠番  馬番   オッズ   ...    \
# 0  2018/04/14   2阪神7  雨  11     アーリントンC(G3) NaN  13   8  13  12.2   ...
# 1  2018/03/17   2中京3  晴  11  中スポ賞ファルコンS(G3) NaN  16   5   9   2.2   ...
# 2  2017/12/17   5阪神6  晴  11  朝日フューチュリティ(G1) NaN  16   6  12   8.7   ...
# 3  2017/10/15   4京都5  雨   9        もみじS(OP) NaN   8   5   5   1.5   ...
# 4  2017/09/24   4阪神7  晴   2           2歳未勝利 NaN  13   3   3   2.2   ...
# 5  2017/09/02  2新潟11  晴   5            2歳新馬 NaN  18   3   6   1.7   ...
#
#     着差  ﾀｲﾑ指数     通過        ペース    上り      馬体重 厩舎ｺﾒﾝﾄ  備考   勝ち馬(2着馬)      賞金
# 0  0.4     **    2-3  34.5-34.7  34.9   466(0)    NaN NaN  タワーオブロンドン   380.0
# 1  0.5     **  12-13  34.9-35.5  34.4  466(-4)    NaN NaN   ミスターメロディ     NaN
# 2  0.7     **  13-13  35.2-34.0  33.8  470(+8)    NaN NaN   ダノンプレミアム   700.0
# 3 -0.5     **    3-3  36.4-34.8  34.2   462(0)    NaN NaN  (アーデルワイゼ)  1618.2
# 4 -0.3     **    7-5  35.1-35.0  34.4  462(-4)    NaN NaN   (ラブカンプー)   500.0
# ...

# %%
tetra_drakma = pd.read_html('http://db.netkeiba.com/horse/result/2015105073/')
tetra_drakma = tetra_drakma[0]
tetra_drakma
# Out:
#            日付    開催  天気   R            レース名  映像  頭数  枠番  馬番   オッズ   ...    \
# 0  2018/02/12  1東京6   晴  11  デイリー杯クイーンC(G3) NaN  16   3   6   5.6   ...
# 1  2018/01/07  1中山2   晴  11      フェアリーS(G3) NaN  16   8  16   3.6   ...
# 2  2017/11/19  5東京6   晴   4           2歳未勝利 NaN  18   6  12   1.3   ...
# 3  2017/10/09  4東京3   晴   2           2歳未勝利 NaN  13   6   9  18.2   ...
# 4  2017/07/22  2福島7  小雨   6            2歳新馬 NaN  16   1   2   4.6   ...
#
#     着差  ﾀｲﾑ指数     通過        ペース    上り      馬体重 厩舎ｺﾒﾝﾄ  備考    勝ち馬(2着馬)      賞金
# 0 -0.1     **    2-1  34.6-35.9  35.9  462(-6)    NaN NaN    (フィニフティ)  3558.1
# 1  0.5     **  5-5-5  35.9-35.0  35.2   468(0)    NaN NaN      プリモシーン     NaN
# 2 -0.8     **    3-3  34.7-34.8  34.6   468(0)    NaN NaN  (ジョブックコメン)   500.0
# 3  0.0     **    3-2  35.9-34.1  34.0   468(0)    NaN NaN      プリモシーン   200.0
# 4  1.6     **  11-11  35.0-36.0  36.0   468(0)    NaN NaN    ラインギャラント     NaN
#
# [5 rows x 28 columns]

# %%
delta_balose = pd.read_html('http://db.netkeiba.com/horse/result/2015110070/')
delta_balose = delta_balose[0]
delta_balose
# Out:
#            日付    開催 天気   R           レース名  映像  頭数  枠番  馬番   オッズ   ...     着差  \
# 0  2018/04/07  3中山5  曇  11  ニュージーランドT(G2) NaN  15   2   2  23.2   ...    0.1
# 1  2018/01/14  1中山5  晴  11        京成杯(G3) NaN  15   6  10   5.0   ...    1.7
# 2  2017/10/21  4東京6  雨   4           2歳新馬 NaN  18   3   5   2.5   ...   -0.7
#
#    ﾀｲﾑ指数       通過        ペース    上り       馬体重 厩舎ｺﾒﾝﾄ  備考   勝ち馬(2着馬)      賞金
# 0     **    8-5-5  35.2-35.1  34.8   502(+4)    NaN NaN        カツジ  1415.8
# 1     **  3-4-4-4  35.4-37.0  37.7  498(+10)    NaN NaN  ジェネラーレウーノ     NaN
# 2     **      2-2  36.7-35.1  35.1    488(0)    NaN NaN  (エフティアテナ)   700.0
#
# [3 rows x 28 columns]

# %%
tosen_bleath = pd.read_html('http://db.netkeiba.com/horse/result/2015104513/')
tosen_bleath = tosen_bleath[0]
tosen_bleath
# Out:
#            日付    開催 天気   R           レース名  映像  頭数  枠番  馬番   オッズ   ...     着差  \
# 0  2018/04/08  2阪神6  晴  11        桜花賞(G1) NaN  17   4   7  42.1   ...    0.7
# 1  2018/03/17  2中山7  晴  11      フラワーC(G3) NaN  13   6   9   6.8   ...    0.0
# 2  2017/12/10  5阪神4  晴  11  阪神ジュベナイルF(G1) NaN  18   4   8  22.5   ...    0.6
# 3  2017/10/28  4東京8  雨  11     アルテミスS(G3) NaN  15   8  14   2.2   ...    0.5
# 4  2017/09/17  4中山4  雨   5           2歳新馬 NaN  16   5   9   4.7   ...   -0.3
#
#    ﾀｲﾑ指数        通過        ペース    上り      馬体重 厩舎ｺﾒﾝﾄ  備考   勝ち馬(2着馬)      賞金
# 0     **     13-13  34.5-34.4  34.2   456(0)    NaN NaN    アーモンドアイ  1600.0
# 1     **  9-9-10-9  36.8-35.5  34.6  456(+2)    NaN NaN     カンタービレ  1413.4
# 2     **     13-15  35.3-34.4  33.7  454(-8)    NaN NaN  ラッキーライラック   980.0
# 3     **      10-7  35.4-35.1  34.9  462(-4)    NaN NaN  ラッキーライラック     NaN
# 4     **  16-14-12  37.0-35.7  34.0   466(0)    NaN NaN   (プリモシーン)   700.0
#
# [5 rows x 28 columns]

# %%
pax_americana = pd.read_html('http://db.netkeiba.com/horse/result/2015105905/')
pax_americana = pax_americana[0]
pax_americana
# Out:
#            日付    開催 天気   R         レース名  映像  頭数  枠番  馬番  オッズ   ...     着差  \
# 0  2018/04/14  2阪神7  雨  11  アーリントンC(G3) NaN  13   1   1  4.7   ...    0.1
# 1  2018/02/10  2京都5  雨   9  こぶし賞(500万下) NaN  14   8  14  4.5   ...   -0.2
# 2  2017/11/11  5京都3  晴   3        2歳未勝利 NaN  12   8  12  3.2   ...   -0.2
# 3  2017/10/15  4京都5  雨   3        2歳未勝利 NaN  11   5   5  7.4   ...    0.2
# 4  2017/08/13  2新潟6  曇   5         2歳新馬 NaN  18   8  16  3.5   ...    0.5
#
#    ﾀｲﾑ指数    通過        ペース    上り       馬体重 厩舎ｺﾒﾝﾄ  備考     勝ち馬(2着馬)      賞金
# 0     **   8-7  34.5-34.7  34.4   462(-8)    NaN NaN    タワーオブロンドン  1513.4
# 1     **  14-6  34.0-37.4  36.2    470(0)    NaN NaN  (ケイアイノーテック)  1032.9
# 2     **   2-2  34.3-35.9  35.8  470(-12)    NaN NaN       (ラセット)   500.0
# 3     **   3-4  36.6-34.7  34.4   482(-6)    NaN NaN      メガリージョン   130.0
# 4     **   7-5  37.5-33.7  33.8    488(0)    NaN NaN      クレバーバード   110.0
#
# [5 rows x 28 columns]
